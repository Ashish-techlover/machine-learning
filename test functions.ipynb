# %%
L=[int(x) for x in input().split(",")]
li=[]
for z in L:
    r=pow(10,z)
    for i in range(r)[::-1]:
        if i%z==0:
            li.append(i)
            break
listtostring=','.join(map(str,li))
print(listtostring)
# Out:
# 1,2,3,4,5
# 9,98,999,9996,99995

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np


# %matplotlib notebook
'''
Set the values in the variable x
The function arange helps to generate an array with the 
following parameters arange(start,end,increment)
'''

'''
Now set the formula in the variable y
'''
mycmap = plt.get_cmap('gist_earth')
x = np.outer(np.linspace(-10, 10, 100), np.ones(100))
y = x.copy().T # transpose
z = -x**2+(np.cos(x**2)+1/np.sin(x**2))+100
fig = plt.figure(figsize =(18, 9))
ax = plt.axes(projection ='3d')
  
# Creating plot
ax.plot_surface(x, y, z,cmap=mycmap)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1800">

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np
'''
Set the values in the variable x
The function arange helps to generate an array with the 
following parameters arange(start,end,increment)
'''
'''
Now set the formula in the variable y
'''
mycmap = plt.get_cmap('coolwarm')
x = np.outer(np.linspace(-10, 10, 32), np.ones(32))
y = x.copy().T # transpose
z = -x**2+5*x + 20
fig = plt.figure(figsize =(10, 5))
ax = plt.axes(projection ='3d')
  
# Creating plot
ax.plot_surface(x, y, z,cmap=mycmap)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
import matplotlib.pyplot as plt
import numpy as np
'''
Set the values in the variable x
The function arange helps to generate an array with the 
following parameters arange(start,end,increment)
'''

'''
Now set the formula in the variable y
'''
mycmap = plt.get_cmap('coolwarm')
x = np.outer(np.linspace(-8, 8, 100), np.ones(100))
y = x.copy().T # transpose
z = -x**2
fig = plt.figure(figsize =(10, 5))
ax = plt.axes(projection ='3d')
  
# Creating plot
ax.plot_surface(x, y, z,cmap=mycmap)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
'''
Set the values in the variable x
The function arange helps to generate an array with the 
following parameters arange(start,end,increment)
'''
x1 = np.arange(-16,16,1)
x2 = np.arange(-16,16,1)
'''
Now set the formula in the variable y
'''
x1 = np.outer(np.linspace(-10, 10, 32), np.ones(32))
y = x1.copy().T # transpose
z = -np.pi*x1**2-x2**2*np.cos(-x1)
mycmap = plt.get_cmap('coolwarm')
fig = plt.figure(figsize =(10, 5))
ax = plt.axes(projection ='3d')
  
# Creating plot
ax.plot_surface(x1, y, z,cmap=mycmap)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
np.pi
# Out:
# 3.141592653589793

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np
import math
# %matplotlib notebook
'''
Set the values in the variable x
The function arange helps to generate an array with the 
following parameters arange(start,end,increment)
'''


'''
Now set the formula in the variable y
'''
x1 = np.outer(np.linspace(-20, 20, 32), np.ones(32))
y = x1.copy().T # transpose
z = (-x1**2-y**2)*np.exp(np.sin((1/50*x1**2)+(1/50*y**2)))-20*np.cos(2*np.pi*x1)-20*np.cos(2*np.pi*y)
mycmap = plt.get_cmap('coolwarm')
fig = plt.figure(figsize =(10, 5))
ax = plt.axes(projection ='3d')
  
# Creating plot
ax.plot_surface(x1, y, z,cmap=mycmap)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np
import math
# %matplotlib notebook
'''
Set the values in the variable x
The function arange helps to generate an array with the 
following parameters arange(start,end,increment)
'''


'''
Now set the formula in the variable y
'''
x1 = np.outer(np.linspace(-50, 50, 100), np.ones(100))
y = x1.copy().T # transpose
z = (-x1**2-y**2)*np.exp(np.sin((1/50*x1**2)+(1/50*y**2)))
mycmap = plt.get_cmap('coolwarm')
fig = plt.figure(figsize =(10, 5))
ax = plt.axes(projection ='3d')
  
# Creating plot
ax.plot_surface(x1, y, z,cmap=mycmap)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
'''
Set the values in the variable x
The function arange helps to generate an array with the 
following parameters arange(start,end,increment)
'''


x2 = np.arange(-10,10,1)
'''
Now set the formula in the variable y
'''
x1 = np.outer(np.linspace(-10, 10, 20), np.ones(20))
y = x1.copy().T # transpose
z = 0.26*(x1**2+x2**2)-x1*x2
mycmap = plt.get_cmap('coolwarm')
fig = plt.figure(figsize =(10, 5))
ax = plt.axes(projection ='3d')
  
# Creating plot
ax.plot_surface(x1, y, z,cmap=mycmap)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# inverse rastrigin_graph.py

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm 
from mpl_toolkits.mplot3d import Axes3D 
# %matplotlib notebook
X = np.linspace(-5.12, 5.12, 100)     
Y = np.linspace(-5.12, 5.12, 100)     
X, Y = np.meshgrid(X, Y) 

Z = (-X**2 - 10 * np.cos(2 * np.pi * X)) + (-Y**2 - 10 * np.cos(2 * np.pi * Y)) + 20
fig = plt.figure() 
ax = fig.gca(projection='3d') 
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
  cmap=cm.nipy_spectral, linewidth=0.08,
  antialiased=True)    
# plt.savefig('rastrigin_graph.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm 
from mpl_toolkits.mplot3d import Axes3D 
 
X = np.linspace(-5.12, 5.12, 100)     
Y = np.linspace(-5.12, 5.12, 100)     
X, Y = np.meshgrid(X, Y) 

Z = (-X**2 ) + (-Y**2 ) -25*np.sin(500*X**4)*np.cos(500*Y**4)
fig = plt.figure() 
ax = fig.gca(projection='3d') 
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
  cmap=cm.nipy_spectral, linewidth=0.08,
  antialiased=True)    
# plt.savefig('rastrigin_graph.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import math
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
def rastrigin(*X, **kwargs):
    A = kwargs.get('A', 10)
    return A + sum([(x**2 - A * np.cos(2 * math.pi * x)) for x in X])

if __name__ == '__main__':
    X = np.linspace(-8, 8, 200)    
    #Y = np.linspace(-8, 8, 200) 
    Y=X

    X, Y = np.meshgrid(X, Y)

    Z = rastrigin(X,Y ,A=10)

    fig = plt.figure()
    ax = fig.gca(projection='3d')

    ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.plasma, linewidth=0, antialiased=False)    
    plt.savefig('rastrigin.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
X
# Out:
# array([[-8.        , -7.91959799, -7.83919598, ...,  7.83919598,
#          7.91959799,  8.        ],
#        [-8.        , -7.91959799, -7.83919598, ...,  7.83919598,
#          7.91959799,  8.        ],
#        [-8.        , -7.91959799, -7.83919598, ...,  7.83919598,
#          7.91959799,  8.        ],
#        ...,
#        [-8.        , -7.91959799, -7.83919598, ...,  7.83919598,
#          7.91959799,  8.        ],
#        [-8.        , -7.91959799, -7.83919598, ...,  7.83919598,
#          7.91959799,  8.        ],
#        [-8.        , -7.91959799, -7.83919598, ...,  7.83919598,
#          7.91959799,  8.        ]])

# %%
Y
# Out:
# array([[-8.        , -8.        , -8.        , ..., -8.        ,
#         -8.        , -8.        ],
#        [-7.91959799, -7.91959799, -7.91959799, ..., -7.91959799,
#         -7.91959799, -7.91959799],
#        [-7.83919598, -7.83919598, -7.83919598, ..., -7.83919598,
#         -7.83919598, -7.83919598],
#        ...,
#        [ 7.83919598,  7.83919598,  7.83919598, ...,  7.83919598,
#          7.83919598,  7.83919598],
#        [ 7.91959799,  7.91959799,  7.91959799, ...,  7.91959799,
#          7.91959799,  7.91959799],
#        [ 8.        ,  8.        ,  8.        , ...,  8.        ,
#          8.        ,  8.        ]])

# %%
import math
import numpy as np
X = np.linspace(-4, 4, 200)    
Y = np.linspace(-4, 4, 200)    

def rastrigin(*X, **kwargs):
    A = kwargs.get('A', 10)
    return A + sum([(x**2 - A * np.cos(2 * math.pi * x)) for x in X])

# %%
rastrigin(X,Y, A=10)
# Out:
# array([[22.        , 21.99732503, 22.61237818, ..., 22.61237818,
#         21.99732503, 22.        ],
#        [21.99732503, 21.99465005, 22.6097032 , ..., 22.6097032 ,
#         21.99465005, 21.99732503],
#        [22.61237818, 22.6097032 , 23.22475636, ..., 23.22475636,
#         22.6097032 , 22.61237818],
#        ...,
#        [22.61237818, 22.6097032 , 23.22475636, ..., 23.22475636,
#         22.6097032 , 22.61237818],
#        [21.99732503, 21.99465005, 22.6097032 , ..., 22.6097032 ,
#         21.99465005, 21.99732503],
#        [22.        , 21.99732503, 22.61237818, ..., 22.61237818,
#         21.99732503, 22.        ]])

# %%
  X = np.linspace(-8, 8, 200)

# %%
X
# Out:
# array([-8.        , -7.91959799, -7.83919598, -7.75879397, -7.67839196,
#        -7.59798995, -7.51758794, -7.43718593, -7.35678392, -7.27638191,
#        -7.1959799 , -7.11557789, -7.03517588, -6.95477387, -6.87437186,
#        -6.79396985, -6.71356784, -6.63316583, -6.55276382, -6.47236181,
#        -6.3919598 , -6.31155779, -6.23115578, -6.15075377, -6.07035176,
#        -5.98994975, -5.90954774, -5.82914573, -5.74874372, -5.66834171,
#        -5.5879397 , -5.50753769, -5.42713568, -5.34673367, -5.26633166,
#        -5.18592965, -5.10552764, -5.02512563, -4.94472362, -4.86432161,
#        -4.7839196 , -4.70351759, -4.62311558, -4.54271357, -4.46231156,
#        -4.38190955, -4.30150754, -4.22110553, -4.14070352, -4.06030151,
#        -3.9798995 , -3.89949749, -3.81909548, -3.73869347, -3.65829146,
#        -3.57788945, -3.49748744, -3.41708543, -3.33668342, -3.25628141,
#        -3.1758794 , -3.09547739, -3.01507538, -2.93467337, -2.85427136,
# ...

# %%
Y = np.linspace(-8, 8, 200)

# %%
Y
# Out:
# array([-8.        , -7.91959799, -7.83919598, -7.75879397, -7.67839196,
#        -7.59798995, -7.51758794, -7.43718593, -7.35678392, -7.27638191,
#        -7.1959799 , -7.11557789, -7.03517588, -6.95477387, -6.87437186,
#        -6.79396985, -6.71356784, -6.63316583, -6.55276382, -6.47236181,
#        -6.3919598 , -6.31155779, -6.23115578, -6.15075377, -6.07035176,
#        -5.98994975, -5.90954774, -5.82914573, -5.74874372, -5.66834171,
#        -5.5879397 , -5.50753769, -5.42713568, -5.34673367, -5.26633166,
#        -5.18592965, -5.10552764, -5.02512563, -4.94472362, -4.86432161,
#        -4.7839196 , -4.70351759, -4.62311558, -4.54271357, -4.46231156,
#        -4.38190955, -4.30150754, -4.22110553, -4.14070352, -4.06030151,
#        -3.9798995 , -3.89949749, -3.81909548, -3.73869347, -3.65829146,
#        -3.57788945, -3.49748744, -3.41708543, -3.33668342, -3.25628141,
#        -3.1758794 , -3.09547739, -3.01507538, -2.93467337, -2.85427136,
# ...

# %%
letters = ['a', 'b', 'c']
numbers = [0, 1, 2]
for l, n in zip(letters, numbers):
    print(f'Letter: {l}',f'Number: {n}')
# Out:
# Letter: a Number: 0
# Letter: b Number: 1
# Letter: c Number: 2

# %%
letters = [2,3,4]
numbers = [4,3,2]
for l, n in zip(letters, numbers):
    print(l*n)
# Out:
# 8
# 9
# 8

# %%
letters = [2,3,4]
numbers = letters[::-1]
for l in letters:
    for n in numbers:
        print(l*n)
# Out:
# 8
# 6
# 4
# 12
# 9
# 6
# 16
# 12
# 8

# %%
a=np.array([numbers])

# %%
a.shape
# Out:
# (1, 3)

# %%
a=a.T

# %%
a.shape
# Out:
# (3, 1)

# %%
a.ndim
# Out:
# 2

# %%
import numpy as np
c=[4,7,3,4,56,78,0]
d=c

# %%
d
# Out:
# [4, 7, 3, 4, 56, 78, 0]

# %%
x=np.array([[1,2,3],[2,3,4]])
y=x[::-1]

# %%
x
# Out:
# array([[1, 2, 3],
#        [2, 3, 4]])

# %%
y
# Out:
# array([[2, 3, 4],
#        [1, 2, 3]])

# %%
C=np.array([c])
D=C.T

# %%
C,D
# Out:
# (array([[ 4,  7,  3,  4, 56, 78,  0]]), array([[ 4],
#         [ 7],
#         [ 3],
#         [ 4],
#         [56],
#         [78],
#         [ 0]]))

# %%
x=C*D
x
# Out:
# array([[  16,   28,   12,   16,  224,  312,    0],
#        [  28,   49,   21,   28,  392,  546,    0],
#        [  12,   21,    9,   12,  168,  234,    0],
#        [  16,   28,   12,   16,  224,  312,    0],
#        [ 224,  392,  168,  224, 3136, 4368,    0],
#        [ 312,  546,  234,  312, 4368, 6084,    0],
#        [   0,    0,    0,    0,    0,    0,    0]])

# %%
x.shape,x.ndim
# Out:
# ((7, 7), 2)

# %%
for i in C:
    for j in D:
        print(i*j)
# Out:
# [ 16  28  12  16 224 312   0]
# [ 28  49  21  28 392 546   0]
# [ 12  21   9  12 168 234   0]
# [ 16  28  12  16 224 312   0]
# [ 224  392  168  224 3136 4368    0]
# [ 312  546  234  312 4368 6084    0]
# [0 0 0 0 0 0 0]

# %%
for i in C:
    print(i)
# Out:
# [ 4  7  3  4 56 78  0]

# %%
C.shape,C.ndim,D.shape,D.ndim
# Out:
# ((1, 7), 2, (7, 1), 2)

# %%
for k in C:
    for l in k:
        print(l)
# Out:
# 4
# 7
# 3
# 4
# 56
# 78
# 0

# %%
C**2
# Out:
# array([[  16,   49,    9,   16, 3136, 6084,    0]], dtype=int32)

# %%
for i in C:
    print(i)
# Out:
# [ 4  7  3  4 56 78  0]

# %%
c=np.array([[4,7,3,4,56,78,0],[1,2,3,4,5,6,7]])
c
# Out:
# array([[ 4,  7,  3,  4, 56, 78,  0],
#        [ 1,  2,  3,  4,  5,  6,  7]])

# %%
for i in c:
    print(i)
# Out:
# [ 4  7  3  4 56 78  0]
# [1 2 3 4 5 6 7]

# %%
C*C
# Out:
# array([[  16,   49,    9,   16, 3136, 6084,    0]])

# %%
C[-1]*D
# Out:
# array([[  16,   28,   12,   16,  224,  312,    0],
#        [  28,   49,   21,   28,  392,  546,    0],
#        [  12,   21,    9,   12,  168,  234,    0],
#        [  16,   28,   12,   16,  224,  312,    0],
#        [ 224,  392,  168,  224, 3136, 4368,    0],
#        [ 312,  546,  234,  312, 4368, 6084,    0],
#        [   0,    0,    0,    0,    0,    0,    0]])

# %%
D[-1]
# Out:
# array([0])

# %%
for i in C[-1]:
    for j in D:
        i*j

# %%
d
# Out:
# array([0])

# %%
D
# Out:
# array([[ 4],
#        [ 7],
#        [ 3],
#        [ 4],
#        [56],
#        [78],
#        [ 0]])
